# %%
from cloudscraper import create_scraper
import pandas as pd
from bs4 import BeautifulSoup

# %%
scraper = create_scraper()

# %%
response = scraper.get('https://www.speedtest.net/global-index')
soup = BeautifulSoup(response.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-P8PJJD5');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <title>Speedtest Global Index – Internet Speed around the world – Speedtest Global Index</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Find out which countries have the fastest internet speeds in the world. View global monthly comparisons of fixed and mobile internet speeds." name="description"/>
# <meta content="Speedtest Global Index – Internet Speed around the world – Speedtest Global Index" property="og:title"/>
# ...

# %%
month = soup.select_one('.month').text
names = soup.select('.graph')
all_names = []
for name in names:
    all_name = name['id'].split('-')[1]
    all_names.append(all_name)

res = []
for i in all_names:
    if i not in res:
        res.append(i)

# %%
tables = pd.read_html(response.text)

# %%
all_tables = []
for i in range(len(tables)):
    tables[i]['Month'] = month
    tables[i]['Name'] = res[i]
    tables[i].drop(columns=['#', '#.1'], inplace=True, axis=1)
    tables[i].dropna(inplace=True, ignore_index=True) # drop rows with NA values, ignore_index to retain 0,1,2...index
    all_tables.append(tables[i])
# Out:
# Bad pipe message: %s [b'\xae\xa7\x0bL$\xe4\n\xa3(80Bm\x853jJ\x9e \xa2\xb2\xdb\t\x8c\xc3\x1f\nIO\xc4\xc9\xb4\xc25\x00o\xc23xLzln\xb8V\xfb\xcb']
# Bad pipe message: %s [b'\r1\x00', b'\x02\x13\x03\x13\x01\x00\xff', b'']
# Bad pipe message: %s [b"&\xbft\x12\xe1s\x1eo\x13})\xd5j\x0e\xc3\x1b\x8b\xe8\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0", b'9\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q']
# Bad pipe message: %s [b'u6\xdd\xa0\x8b\xdc-\xfe\xe2V\xdf@#\xdf\xeb\xf1\xc6\x88\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00']
# ...
